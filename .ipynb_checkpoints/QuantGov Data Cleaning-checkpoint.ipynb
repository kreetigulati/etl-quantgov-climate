# %%
import pandas as pd

# %%
fed_reg_df = pd.read_csv("fed_reg_data2.csv")

# %%
fed_reg_df
# Out:
#      Unnamed: 0  seriesValue  seriesID                    seriesName  topicID  \
# 0             0        362.0        13  Total Restrictions by Agency        1
# 1             1        249.0        13  Total Restrictions by Agency        1
# 2             2        514.0        13  Total Restrictions by Agency        1
# 3             3        162.0        13  Total Restrictions by Agency        1
# 4             4     173206.0        13  Total Restrictions by Agency        1
# ..          ...          ...       ...                           ...      ...
# 138         138        463.0        13  Total Restrictions by Agency        1
# 139         139         74.0        13  Total Restrictions by Agency        1
# 140         140     157737.0        13  Total Restrictions by Agency        1
# 141         141         65.0        13  Total Restrictions by Agency        1
# 142         142        392.0        13  Total Restrictions by Agency        1
#
# ...
