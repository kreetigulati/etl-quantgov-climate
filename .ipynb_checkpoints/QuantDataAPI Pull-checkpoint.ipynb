# %%
#import dependencies including regcensus - QuantGov API library
import regcensus as rc
import requests
import pandas as pd

# %%
#Check full list of jurisdictions available
juris = rc.list_jurisdictions()

# %%
#Check all agencies available for the Federal Government of the United States 
rc.list_agencies(38)
# Out:
# {'ACTION': 158,
#  'AbilityOne': 145,
#  'Administrative Conference of the United States': 195,
#  'Administrator of the Emergency Natural Gas Act': 226,
#  'Advisory Commission On Intergovernmental Relations': 75,
#  'Advisory Committee On Federal Pay': 183,
#  'Advisory Council On Historic Preservation': 163,
#  'African Development Foundation': 138,
#  'Air Transportation System Stabilization': 204,
#  'Alaska Natural Gas Transportation System': 101,
#  'American Battle Monuments Commission': 104,
#  'American Revolution Bicentennial Administration': 112,
#  'Anadromous Fisheries': 82,
#  'Appalachian Regional Commission': 85,
#  'Architectural and Transportation Barriers Compliance Board': 246,
#  'Arctic Research Commission': 210,
#  'Armed Forces Retirement Home': 134,
#  'Assassination Records Review Board': 176,
#  'Automotive Agreement Adjustment Assistance Board': 211,
#  'Board For International Broadcasting': 126,
# ...

# %%
#Using (38) United States jurisdiction, for years 2000-2020, pulling reg data from 9 federal agencies with regulate climate and the environment
fed_reg_data = rc.get_values(series=[13], jurisdiction=38, date=[2000, 2001, 2002, 2003 ,2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2014, 2015, 2016, 2017, 2018, 2019, 2020], agency =[87, 219, 201, 222, 232, 72, 247, 132, 91], documentType=1, verbose=1)
# Out:
# API call: https://api.quantgov.org/values?series=13&jurisdiction=38&agency=87,219,201,222,232,72,247,132,91&date=2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2014,2015,2016,2017,2018,2019,2020&documentType=1

# %%
#Export data to csv for cleaning
fed_reg_data.to_csv('fed_reg_data2.csv')
