# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib as plt
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('us_disaster_declarations.csv')
df.head(10)
# Out:
#   fema_declaration_string  disaster_number state declaration_type  \
# 0                 DR-1-GA                1    GA               DR
# 1                 DR-2-TX                2    TX               DR
# 2                 DR-3-LA                3    LA               DR
# 3                 DR-4-MI                4    MI               DR
# 4                 DR-5-MT                5    MT               DR
# 5                 DR-6-MI                6    MI               DR
# 6                 DR-7-MA                7    MA               DR
# 7                 DR-8-IA                8    IA               DR
# 8                 DR-9-TX                9    TX               DR
# 9                DR-11-NH               11    NH               DR
#
#        declaration_date  fy_declared incident_type         declaration_title  \
# 0  1953-05-02T00:00:00Z         1953       Tornado                   Tornado
# 1  1953-05-15T00:00:00Z         1953       Tornado  Tornado & Heavy Rainfall
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61895 entries, 0 to 61894
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   fema_declaration_string     61895 non-null  object
#  1   disaster_number             61895 non-null  int64
#  2   state                       61895 non-null  object
#  3   declaration_type            61895 non-null  object
#  4   declaration_date            61895 non-null  object
#  5   fy_declared                 61895 non-null  int64
#  6   incident_type               61895 non-null  object
#  7   declaration_title           61895 non-null  object
#  8   ih_program_declared         61895 non-null  int64
#  9   ia_program_declared         61895 non-null  int64
#  10  pa_program_declared         61895 non-null  int64
#  11  hm_program_declared         61895 non-null  int64
#  12  incident_begin_date         61895 non-null  object
# ...

# %%
disaster_types = df['incident_type'].unique()
print("Types of Disasters reported:\n\n", disaster_types)
print("Occurrences:\n\n",df['incident_type'].value_counts())
# Out:
# Types of Disasters reported:
#
#  ['Tornado' 'Flood' 'Fire' 'Other' 'Earthquake' 'Hurricane' 'Volcano'
#  'Severe Storm(s)' 'Toxic Substances' 'Typhoon' 'Drought'
#  'Dam/Levee Break' 'Snow' 'Severe Ice Storm' 'Freezing' 'Coastal Storm'
#  'Fishing Losses' 'Mud/Landslide' 'Human Cause' 'Terrorist' 'Tsunami'
#  'Chemical' 'Biological']
# Occurrences:
#
#  Severe Storm(s)     17026
# Hurricane           12005
# Flood               10453
# Biological           7811
# Snow                 3664
# Fire                 3511
# Severe Ice Storm     2937
# Tornado              1488
# Drought              1292
# Coastal Storm         570
# Freezing              301
# Other                 299
# Earthquake            227
# Typhoon               130
# Volcano                51
# Fishing Losses         42
# Mud/Landslide          36
# Dam/Levee Break        13
# Toxic Substances        9
# Chemical                9
# Tsunami                 9
# Human Cause             7
# ...

# %%
m=df[['state','incident_type']].groupby('state').describe()
m['incident_type'].sort_values(by='count',ascending=False)
# Out:
#       count unique              top  freq
# state
# TX     5164     11        Hurricane  1303
# MO     2670      8  Severe Storm(s)  1309
# KY     2510     10  Severe Storm(s)   986
# VA     2493     11        Hurricane   877
# OK     2461      9  Severe Storm(s)   996
# LA     2299     11        Hurricane  1236
# GA     2269     10        Hurricane   905
# FL     2027     10        Hurricane   989
# NC     1984     10        Hurricane  1192
# PR     1826      8        Hurricane   868
# IA     1823      8            Flood   722
# MS     1731      8  Severe Storm(s)   638
# KS     1682      9  Severe Storm(s)   975
# AL     1650      8        Hurricane   611
# AR     1588      8  Severe Storm(s)   633
# TN     1560      9  Severe Storm(s)   742
# MN     1498     10            Flood   642
# IN     1451      7  Severe Storm(s)   655
# CA     1443     13             Fire   433
# NE     1423      9  Severe Storm(s)   630
# NY     1422     13  Severe Storm(s)   368
# ...

# %%
m['incident_type'].sort_values(by='freq',ascending=False)['freq']
# Out:
# state
# MO    1309
# TX    1303
# LA    1236
# NC    1192
# OK     996
# FL     989
# KY     986
# KS     975
# GA     905
# VA     877
# PR     868
# TN     742
# IA     722
# IN     655
# ND     653
# MN     642
# MS     638
# AR     633
# NE     630
# ME     623
# AL     611
# OH     566
# WV     460
# SD     457
# SC     449
# CA     433
# NY     368
# PA     349
# IL     316
# WI     293
# WA     255
# MI     188
# OR     158
# NJ     151
# MD     151
# NM     150
# CO     149
# VT     145
# MT     143
# AK     121
# NH     108
# ID      93
# MA      93
# NV      88
# AZ      85
# CT      79
# UT      73
# VI      53
# MP      53
# WY      48
# RI      37
# MH      25
# AS      25
# FM      23
# HI      22
# DE      21
# GU      13
# DC       9
# PW       1
# Name: freq, dtype: object

# %%
df.columns
# Out:
# Index(['fema_declaration_string', 'disaster_number', 'state',
#        'declaration_type', 'declaration_date', 'fy_declared', 'incident_type',
#        'declaration_title', 'ih_program_declared', 'ia_program_declared',
#        'pa_program_declared', 'hm_program_declared', 'incident_begin_date',
#        'incident_end_date', 'disaster_closeout_date', 'fips', 'place_code',
#        'designated_area', 'declaration_request_number', 'hash', 'last_refresh',
#        'id'],
#       dtype='object')

# %%
df['fy_declared']
# Out:
# 0        1953
# 1        1953
# 2        1953
# 3        1953
# 4        1953
#          ...
# 61890    2021
# 61891    2021
# 61892    2021
# 61893    2021
# 61894    2021
# Name: fy_declared, Length: 61895, dtype: int64

# %%
df_century = df[df['fy_declared'] >= 2000]
df_century
# Out:
#       fema_declaration_string  disaster_number state declaration_type  \
# 19525              EM-3150-FL             3150    FL               EM
# 19526              EM-3150-FL             3150    FL               EM
# 19527              EM-3150-FL             3150    FL               EM
# 19528              EM-3150-FL             3150    FL               EM
# 19529              EM-3150-FL             3150    FL               EM
# ...                       ...              ...   ...              ...
# 61890              FM-5389-AZ             5389    AZ               FM
# 61891              FM-5389-AZ             5389    AZ               FM
# 61892              FM-5390-NV             5390    NV               FM
# 61893              FM-5391-UT             5391    UT               FM
# 61894              FM-5392-MT             5392    MT               FM
#
#            declaration_date  fy_declared incident_type  \
# 19525  1999-10-15T18:15:00Z         2000     Hurricane
# ...

# %%
df_century.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42370 entries, 19525 to 61894
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   fema_declaration_string     42370 non-null  object
#  1   disaster_number             42370 non-null  int64
#  2   state                       42370 non-null  object
#  3   declaration_type            42370 non-null  object
#  4   declaration_date            42370 non-null  object
#  5   fy_declared                 42370 non-null  int64
#  6   incident_type               42370 non-null  object
#  7   declaration_title           42370 non-null  object
#  8   ih_program_declared         42370 non-null  int64
#  9   ia_program_declared         42370 non-null  int64
#  10  pa_program_declared         42370 non-null  int64
#  11  hm_program_declared         42370 non-null  int64
#  12  incident_begin_date         42370 non-null  object
# ...

# %%
df_century = df_century[['id', 'disaster_number','state', 'declaration_type', 'declaration_date', 'fy_declared', 'incident_type', 'declaration_title', 'place_code', 'designated_area']]
df_century = df_century.reset_index(drop = True)
df_century
# Out:
#                              id  disaster_number state declaration_type  \
# 0      60c3b852a0ee349d7109be2c             3150    FL               EM
# 1      60c3b852a0ee349d7109be23             3150    FL               EM
# 2      60c3b852a0ee349d7109be21             3150    FL               EM
# 3      60c3b852a0ee349d7109be29             3150    FL               EM
# 4      60c3b852a0ee349d7109be7d             3150    FL               EM
# ...                         ...              ...   ...              ...
# 42365  60c3b876a0ee349d710bfeab             5389    AZ               FM
# 42366  60c3b876a0ee349d710bfe98             5389    AZ               FM
# 42367  60c3b876a0ee349d710bfe9a             5390    NV               FM
# 42368  60c3b876a0ee349d710bfe96             5391    UT               FM
# 42369  60ca5411a0ee349d719bcf01             5392    MT               FM
#
#            declaration_date  fy_declared incident_type  \
# ...

# %%
disaster_types = df_century['incident_type'].unique()
print("Types of Disasters reported:\n\n", disaster_types)
print("Occurrences:\n\n",df['incident_type'].value_counts())
# Out:
# Types of Disasters reported:
#
#  ['Hurricane' 'Severe Storm(s)' 'Fire' 'Tornado' 'Snow' 'Flood'
#  'Earthquake' 'Other' 'Severe Ice Storm' 'Freezing' 'Coastal Storm'
#  'Terrorist' 'Typhoon' 'Dam/Levee Break' 'Drought' 'Tsunami'
#  'Mud/Landslide' 'Chemical' 'Volcano' 'Toxic Substances' 'Biological']
# Occurrences:
#
#  Severe Storm(s)     17026
# Hurricane           12005
# Flood               10453
# Biological           7811
# Snow                 3664
# Fire                 3511
# Severe Ice Storm     2937
# Tornado              1488
# Drought              1292
# Coastal Storm         570
# Freezing              301
# Other                 299
# Earthquake            227
# Typhoon               130
# Volcano                51
# Fishing Losses         42
# Mud/Landslide          36
# Dam/Levee Break        13
# Toxic Substances        9
# Chemical                9
# Tsunami                 9
# Human Cause             7
# Terrorist               5
# ...

# %%
declaration_type = df['declaration_type'].unique()
declaration_type
# Out:
# array(['DR', 'FM', 'EM'], dtype=object)

# %%
df_century['declaration_type'].value_counts()
# Out:
# DR    26184
# EM    14721
# FM     1465
# Name: declaration_type, dtype: int64

# %%
df_century[['incident_type', 'declaration_type']]
# Out:
#       incident_type declaration_type
# 0         Hurricane               EM
# 1         Hurricane               EM
# 2         Hurricane               EM
# 3         Hurricane               EM
# 4         Hurricane               EM
# ...             ...              ...
# 42365          Fire               FM
# 42366          Fire               FM
# 42367          Fire               FM
# 42368          Fire               FM
# 42369          Fire               FM
#
# [42370 rows x 2 columns]

# %%
m=df_century[['state','incident_type']].groupby('state').describe()
m['incident_type'].sort_values(by='count',ascending=False)
# Out:
#       count unique              top  freq
# state
# TX     3717      9        Hurricane  1227
# MO     2042      6  Severe Storm(s)  1077
# OK     2022      8  Severe Storm(s)   838
# LA     1793     10        Hurricane  1090
# KY     1717      8  Severe Storm(s)   792
# GA     1600      6        Hurricane   848
# VA     1484      8        Hurricane   689
# FL     1361      6        Hurricane   835
# KS     1350      7  Severe Storm(s)   882
# NC     1323      7        Hurricane   898
# PR     1149      6        Hurricane   573
# IA     1131      6  Severe Storm(s)   587
# MS     1129      6        Hurricane   487
# AR     1118      6  Severe Storm(s)   537
# AL     1099      5        Hurricane   532
# NE     1074      8  Severe Storm(s)   561
# NY     1011     10  Severe Storm(s)   320
# TN      967      8  Severe Storm(s)   492
# IN      966      6  Severe Storm(s)   528
# SD      908      6  Severe Storm(s)   312
# OH      856      7  Severe Storm(s)   461
# ...

# %%
df_century = df_century[['id','state', 'declaration_type', 'fy_declared', 'incident_type', 'declaration_title']]
df_century = df_century.reset_index(drop = True)
df_century
# Out:
#                              id state declaration_type  fy_declared  \
# 0      60c3b852a0ee349d7109be2c    FL               EM         2000
# 1      60c3b852a0ee349d7109be23    FL               EM         2000
# 2      60c3b852a0ee349d7109be21    FL               EM         2000
# 3      60c3b852a0ee349d7109be29    FL               EM         2000
# 4      60c3b852a0ee349d7109be7d    FL               EM         2000
# ...                         ...   ...              ...          ...
# 42365  60c3b876a0ee349d710bfeab    AZ               FM         2021
# 42366  60c3b876a0ee349d710bfe98    AZ               FM         2021
# 42367  60c3b876a0ee349d710bfe9a    NV               FM         2021
# 42368  60c3b876a0ee349d710bfe96    UT               FM         2021
# 42369  60ca5411a0ee349d719bcf01    MT               FM         2021
#
#       incident_type               declaration_title
# 0         Hurricane  Tropical Storm Irene - Florida
# ...
