# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
fed_reg_df = pd.read_csv("fed_reg_data2.csv")

# %%
#dropping excess columns
fed_reg_df.drop(['industryCode', "industryName", "occupationName", 'topicID', "footNote", "documentationUrl", "sourceUrl", "Unnamed: 0", "startDate", "endDate"], axis=1)
# Out:
#      seriesValue  seriesID                    seriesName jurisdictionName  \
# 0          362.0        13  Total Restrictions by Agency    United States
# 1          249.0        13  Total Restrictions by Agency    United States
# 2          514.0        13  Total Restrictions by Agency    United States
# 3          162.0        13  Total Restrictions by Agency    United States
# 4       173206.0        13  Total Restrictions by Agency    United States
# ..           ...       ...                           ...              ...
# 138        463.0        13  Total Restrictions by Agency    United States
# 139         74.0        13  Total Restrictions by Agency    United States
# 140     157737.0        13  Total Restrictions by Agency    United States
# 141         65.0        13  Total Restrictions by Agency    United States
# 142        392.0        13  Total Restrictions by Agency    United States
#
#      occupationCode  agencyID  \
# 0                 0        72
# 1                 0        87
# 2                 0        91
# 3                 0       132
# 4                 0       219
# ..              ...       ...
# 138               0        91
# 139               0       201
# 140               0       219
# 141               0       222
# 142               0       232
#
#                                             agencyName  periodCode  \
# 0                   Susquehanna River Basin Commission        2020
# 1                             Marine Mammal Commission        2020
# 2                      Delaware River Basin Commission        2020
# 3             Gulf Coast Ecosystem Restoration Council        2020
# 4                      Environmental Protection Agency        2020
# ..                                                 ...         ...
# 138                    Delaware River Basin Commission        2011
# 139  Morris K. Udall Scholarship and Excellence In ...        2011
# 140                    Environmental Protection Agency        2011
# 141  Utah Reclamation Mitigation and Conservation C...        2011
# 142                            Water Resources Council        2011
#
#                                         sourceCitation  \
# 0    Patrick McLaughlin, Jonathan Nelson, Thurston ...
# 1    Patrick McLaughlin, Jonathan Nelson, Thurston ...
# 2    Patrick McLaughlin, Jonathan Nelson, Thurston ...
# 3    Patrick McLaughlin, Jonathan Nelson, Thurston ...
# 4    Patrick McLaughlin, Jonathan Nelson, Thurston ...
# ..                                                 ...
# 138  Patrick McLaughlin, Jonathan Nelson, Thurston ...
# 139  Patrick McLaughlin, Jonathan Nelson, Thurston ...
# 140  Patrick McLaughlin, Jonathan Nelson, Thurston ...
# 141  Patrick McLaughlin, Jonathan Nelson, Thurston ...
# 142  Patrick McLaughlin, Jonathan Nelson, Thurston ...
#
#                           sourceName  \
# 0    RegData US 4.0 Annual (dataset)
# 1    RegData US 4.0 Annual (dataset)
# 2    RegData US 4.0 Annual (dataset)
# 3    RegData US 4.0 Annual (dataset)
# 4    RegData US 4.0 Annual (dataset)
# ..                               ...
# 138  RegData US 4.0 Annual (dataset)
# 139  RegData US 4.0 Annual (dataset)
# 140  RegData US 4.0 Annual (dataset)
# 141  RegData US 4.0 Annual (dataset)
# 142  RegData US 4.0 Annual (dataset)
#
#                              sourceOrganization
# 0    Mercatus Center at George Mason University
# 1    Mercatus Center at George Mason University
# 2    Mercatus Center at George Mason University
# 3    Mercatus Center at George Mason University
# 4    Mercatus Center at George Mason University
# ..                                          ...
# 138  Mercatus Center at George Mason University
# 139  Mercatus Center at George Mason University
# 140  Mercatus Center at George Mason University
# 141  Mercatus Center at George Mason University
# 142  Mercatus Center at George Mason University
#
# [143 rows x 11 columns]

# %%
fed_reg_table = fed_reg_df[['seriesValue', 'agencyID', 'agencyName']]
fed_reg_table
# Out:
#      seriesValue  agencyID                                         agencyName
# 0          362.0        72                 Susquehanna River Basin Commission
# 1          249.0        87                           Marine Mammal Commission
# 2          514.0        91                    Delaware River Basin Commission
# 3          162.0       132           Gulf Coast Ecosystem Restoration Council
# 4       173206.0       219                    Environmental Protection Agency
# ..           ...       ...                                                ...
# 138        463.0        91                    Delaware River Basin Commission
# 139         74.0       201  Morris K. Udall Scholarship and Excellence In ...
# 140     157737.0       219                    Environmental Protection Agency
# 141         65.0       222  Utah Reclamation Mitigation and Conservation C...
# 142        392.0       232                            Water Resources Council
#
# [143 rows x 3 columns]
